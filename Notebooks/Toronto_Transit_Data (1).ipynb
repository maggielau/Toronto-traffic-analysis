# %% [markdown]
# # Toronto Transit Data GTFS (General Transit Feed Specification)
#
#
# ---
#
#
# **Author**: Group 1
#
# **Creation Date**: December 4, 2021
#
# **Revision Date**: December 11, 2021
#
#
# ---
#
#
# **Data Source**: Toronto Transit Commission (TTC) Routes and Schedules
#
# **Data**: https://open.toronto.ca/dataset/ttc-routes-and-schedules/
#
# **Data Dictionary**:
#
# **Data Licence**: See below for full data licence details.
#
# ---

# %% [markdown]
# The data captures information about serious vehicle collisions in the city of Toronto Ontario.
#
# This notebook will prepare the data for analysis.

# %% [markdown]
# Note: In order to run this code you will need to create a shortcut to the shared drive in your Google drive and specify the path to the shortcut in the file_path variable.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import datetime
from IPython.display import display
import plotly.express as px
import plotly.graph_objects as go
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh') 
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')
import seaborn as sns
import csv

# !pip install geopandas
from shapely.geometry import Polygon
from shapely.geometry import Point
import geopandas as gpd
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.1.5)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (3.2.1)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.0)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.20)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.19.5)

# %%
# The below file path is specific to ECHO only
file_path = '/content/drive/MyDrive/Data Science/1-Foundations of Data Science/Foundations of Data Science - Group Project/Data Files/' 
file_ttc='stops.txt'
file_incidents = 'KSI_Incidents.csv'

# %%
# Importing stops data file
file_ttc=pd.read_csv(file_path+file_ttc)
file_ttc.head(3)
# Out:
#    stop_id  stop_code  ... stop_timezone  wheelchair_boarding
# 0      262        662  ...           NaN                    2
# 1      263        929  ...           NaN                    1
# 2      264        940  ...           NaN                    2
#
# [3 rows x 12 columns]

# %%
file_ttc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9476 entries, 0 to 9475
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   stop_id              9476 non-null   int64
#  1   stop_code            9476 non-null   int64
#  2   stop_name            9476 non-null   object
#  3   stop_desc            0 non-null      float64
#  4   stop_lat             9476 non-null   float64
#  5   stop_lon             9476 non-null   float64
#  6   zone_id              0 non-null      float64
#  7   stop_url             0 non-null      float64
#  8   location_type        0 non-null      float64
#  9   parent_station       0 non-null      float64
#  10  stop_timezone        0 non-null      float64
#  11  wheelchair_boarding  9476 non-null   int64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 888.5+ KB

# %%
ttc_stop = file_ttc[['stop_id', 'stop_code','stop_name','stop_lat', 'stop_lon']]
ttc_stop = ttc_stop.rename(columns={'stop_lat': 'latitude','stop_lon':'longitude' })
ttc_stop.head()
# Out:
#    stop_id  stop_code                       stop_name   latitude  longitude
# 0      262        662       Danforth Rd at Kennedy Rd  43.714379 -79.260939
# 1      263        929      Davenport Rd at Bedford Rd  43.674448 -79.399659
# 2      264        940       Davenport Rd at Dupont St  43.675511 -79.401938
# 3      265       1871  Davisville Ave at Cleveland St  43.702088 -79.378112
# 4      266      11700          Disco Rd at Attwell Dr  43.701362 -79.594843

# %%
# create geopanda dataframe add crs lat long
#ttc_stop['geometry'] = list(zip(ttc_stop.longitude, ttc_stop.latitude))
#ttc_stop['geometry'] = ttc_stop['geometry'].apply(Point)
#ttc_stop['latitude'] = round(ttc_stop['latitude'],3)
#ttc_stop['longitude'] = round(ttc_stop['longitude'],3)
ttc_stop['geometry'] = list(zip(ttc_stop.longitude, ttc_stop.latitude))
ttc_stop['geometry'] = ttc_stop['geometry'].apply(Point)
ttc_stop.head(3)
# Out:
#    stop_id  stop_code  ...  longitude                              geometry
# 0      262        662  ... -79.260939  POINT (-79.26093900000001 43.714379)
# 1      263        929  ... -79.399659          POINT (-79.399659 43.674448)
# 2      264        940  ... -79.401938          POINT (-79.401938 43.675511)
#
# [3 rows x 6 columns]

# %%
# reprojecting epsg 4386 (wgs84) to epsg 2019 (mtm nad 27)
crs = {'init': 'epsg:4326'}
ttc_stop = gpd.GeoDataFrame(ttc_stop, crs=crs, geometry='geometry')
ttc_stop = ttc_stop.to_crs({'init': 'epsg:2019'})
# Out:
# /usr/local/lib/python3.7/dist-packages/pyproj/crs/crs.py:131: FutureWarning:
#
# '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#
# /usr/local/lib/python3.7/dist-packages/pyproj/crs/crs.py:131: FutureWarning:
#
# '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6

# %%
# calculating x and y which will be used later to find nearest ttc stop to address 
ttc_stop['x'] = ttc_stop.geometry.x
ttc_stop['y'] = ttc_stop.geometry.y
ttc_stop.head(3)
# Out:
#    stop_id  stop_code  ...              x             y
# 0      262        662  ...  324064.544438  4.841415e+06
# 1      263        929  ...  312891.267226  4.836956e+06
# 2      264        940  ...  312707.354330  4.837074e+06
#
# [3 rows x 8 columns]

# %%
# Importing incident data file
file_incident=pd.read_csv(file_path+file_incidents)
file_incident.head()
# Out:
#    ACCNUM           ACCLASS  ... OTHER_VEH_COUNT NULL_VEH_COUNT
# 0   25301  Non-Fatal Injury  ...               0              0
# 1   26294             Fatal  ...               0              0
# 2   37330  Non-Fatal Injury  ...               0              0
# 3   45664  Non-Fatal Injury  ...               0              0
# 4   56815  Non-Fatal Injury  ...               1              0
#
# [5 rows x 44 columns]

# %%
# Importing incident dataset
incident = file_incident[['ACCLASS', 'FATAL_INJURY_COUNT','LATITUDE','LONGITUDE']]
incident.head(3)
# Out:
#             ACCLASS  FATAL_INJURY_COUNT   LATITUDE  LONGITUDE
# 0  Non-Fatal Injury                   0  43.710967 -79.377116
# 1             Fatal                   1  43.659568 -79.375560
# 2  Non-Fatal Injury                   0  43.649699 -79.433650

# %%
# Reduce the geographical coordinators to 3 decimal points
#ttc_stop['latitude'] = round(ttc_stop['latitude'],3)
#ttc_stop['longitude'] = round(ttc_stop['longitude'],3)
#incident['LATITUDE'] = round(incident['LATITUDE'],3)
#incident['LONGITUDE'] = round(incident['LONGITUDE'],3)
ttc_stop['latitude_3'] = round(ttc_stop['latitude'],3)
ttc_stop['longitude_3'] = round(ttc_stop['longitude'],3)
incident['LATITUDE_3'] = round(incident['LATITUDE'],3)
incident['LONGITUDE_3'] = round(incident['LONGITUDE'],3)

# %%
#result=ttc_stop.append([file_incident])
#result.head(3)
ttc_stop.head(3)
# Out:
#    stop_id  stop_code  ... latitude_3  longitude_3
# 0      262        662  ...     43.714      -79.261
# 1      263        929  ...     43.674      -79.400
# 2      264        940  ...     43.676      -79.402
#
# [3 rows x 10 columns]

# %%
incident.head(3)
# Out:
#             ACCLASS  FATAL_INJURY_COUNT  ...  LATITUDE_3  LONGITUDE_3
# 0  Non-Fatal Injury                   0  ...      43.711      -79.377
# 1             Fatal                   1  ...      43.660      -79.376
# 2  Non-Fatal Injury                   0  ...      43.650      -79.434
#
# [3 rows x 6 columns]

# %%
#df["period"] = df["Year"].astype(str) + df["quarter"]
ttc_stop['coordinator']=ttc_stop['latitude_3'].astype(str)+","+ttc_stop['longitude_3'].astype(str)
incident['coordinator']=incident['LATITUDE_3'].astype(str)+","+incident['LONGITUDE_3'].astype(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#pd.merge(product,customer,on='Product_ID',how='outer')
stop = ttc_stop[['stop_name','latitude', 'longitude','coordinator']]
incident = incident[['ACCLASS', 'FATAL_INJURY_COUNT','LATITUDE','LONGITUDE','coordinator']]
result=pd.merge(incident,stop,on='coordinator',how='left')
result
# Out:
#                ACCLASS  FATAL_INJURY_COUNT  ...   latitude  longitude
# 0     Non-Fatal Injury                   0  ...  43.711241 -79.376822
# 1                Fatal                   1  ...        NaN        NaN
# 2     Non-Fatal Injury                   0  ...  43.649721 -79.433841
# 3     Non-Fatal Injury                   0  ...  43.649825 -79.433524
# 4     Non-Fatal Injury                   0  ...  43.725514 -79.297383
# ...                ...                 ...  ...        ...        ...
# 8962  Non-Fatal Injury                   0  ...        NaN        NaN
# 8963  Non-Fatal Injury                   0  ...  43.691791 -79.570592
# 8964  Non-Fatal Injury                   0  ...  43.691959 -79.570844
# 8965  Non-Fatal Injury                   0  ...  43.691857 -79.571186
# 8966  Non-Fatal Injury                   0  ...  43.677439 -79.352076
#
# [8967 rows x 8 columns]

# %%
result=result.dropna()
result
# Out:
#                ACCLASS  FATAL_INJURY_COUNT  ...   latitude  longitude
# 0     Non-Fatal Injury                   0  ...  43.711241 -79.376822
# 2     Non-Fatal Injury                   0  ...  43.649721 -79.433841
# 3     Non-Fatal Injury                   0  ...  43.649825 -79.433524
# 4     Non-Fatal Injury                   0  ...  43.725514 -79.297383
# 5     Non-Fatal Injury                   0  ...  43.725616 -79.296932
# ...                ...                 ...  ...        ...        ...
# 8960  Non-Fatal Injury                   0  ...  43.752642 -79.516653
# 8963  Non-Fatal Injury                   0  ...  43.691791 -79.570592
# 8964  Non-Fatal Injury                   0  ...  43.691959 -79.570844
# 8965  Non-Fatal Injury                   0  ...  43.691857 -79.571186
# 8966  Non-Fatal Injury                   0  ...  43.677439 -79.352076
#
# [6278 rows x 8 columns]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6278 entries, 0 to 8966
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ACCLASS             6278 non-null   object
#  1   FATAL_INJURY_COUNT  6278 non-null   int64
#  2   LATITUDE            6278 non-null   float64
#  3   LONGITUDE           6278 non-null   float64
#  4   coordinator         6278 non-null   object
#  5   stop_name           6278 non-null   object
#  6   latitude            6278 non-null   float64
#  7   longitude           6278 non-null   float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 441.4+ KB

# %%
# Plot bus stop map
fig = px.scatter_mapbox(result, lat='latitude', lon='longitude',
                        title='Toronto Transit Locations', 
                        color='ACCLASS', 
                        #size='ACCLASS',
                        hover_name='stop_name',
                        opacity=0.5,
                        center={'lat':43.73, 'lon':-79.4},
                        mapbox_style='open-street-map',
                        height=800, width=1000, zoom=10.15)

fig.show()
fig.write_html(file_path+'Toronto Transit map.html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="84c4322a-9bb8-4e0a-83a0-56672f256d6a" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("84c4322a-9bb8-4e0a-83a0-56672f256d6a")) {
#                     Plotly.newPlot(
#                         '84c4322a-9bb8-4e0a-83a0-56672f256d6a',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>ACCLASS=Non-Fatal Injury<br>latitude=%{lat}<br>longitude=%{lon}", "hovertext": ["Eglinton Ave East at Bayview Ave", "Dundas St West at Sheridan Ave", "Dundas St West at Sheridan Ave", "Pharmacy Ave at Eglinton Ave East", "Eglinton Ave East at Pharmacy Ave East Side", "Eglinton Ave East at Pharmacy Ave", "Belfield Rd at Martin Grove Rd", "Martin Grove Rd at Belfield Rd", "Weston Rd at Dora Spencer Rd North Side", "Weston Rd at Dora Spencer Rd", "St Clair Ave West at Glenholme Ave", "St Clair Ave West at Glenholme Ave", "St Clair Ave West at Glenholme Ave West Side", "McLevin Ave at Tapscott Rd West Side", "McLevin Ave at Tapscott Rd", "Tapscott Rd at McLevin Ave", "Morningside Ave at Danzig St", "Morningside Ave at Danzig St", "Bayview Ave at Sheppard Ave East (Bayview Station)", "Bayview Ave at Sheppard Ave East North Side (Bayview Stn)", "Sheppard Ave East at Bayview Ave (Bayview Station)", "Carrier Dr at Albion Rd", "Morningside Ave at Hwy 401 South Side (Wlkwy to Lampman Dr)", "William R Allen Rd at Sheppard Ave West South Side", "William R Allen Rd at Sheppard Ave West", "Sheppard West Station", "Sheppard West Station - Subway Platform", "Sheppard West Station", "Kipling Ave at Lake Shore Blvd West", "Lake Shore Blvd West at Colonel Samuel Smith Park Dr", "Lake Shore Blvd West at Kipling Ave", "Pape Ave at Danforth Ave", "Danforth Ave at Pape Ave", "Danforth Ave at Pape Ave", "Pape Ave at Danforth Ave", "Yonge St at King St East (King Station)", "Yonge St at King St West (King Station)", "Keele St at Ingram Dr", "Gulliver Rd at Keele St", "Jane St at Beverly Hills Dr", "Jane St at Downsview Ave North Side", "Bay St at Lake Shore Blvd W", "Lake Shore Blvd West at Twenty Eighth St", "Lake Shore Blvd West at Twenty Ninth St", "Grandravine Dr at Futura Dr", "Don Mills Rd at Lawrence Ave East South Side", "Don Mills Rd at Lawrence Ave East", "Lawrence Ave East at Don Mills Rd", "Old Weston Rd at St Clair Ave West", "St Clair Ave West at Old Weston Rd", "King St East at Sherbourne St", "Sherbourne St at King St East", "Sherbourne St at Front St East", "King St East at Sherbourne St", "Sherbourne St at King St East", "Yonge St at Park Home Ave (North York Centre Station)", "Yonge St at Empress Ave (North York Centre Station)", "North York Centre Station - Northbound Platform", "John Garland Blvd at Finch Ave West", "Finch Ave West at Silverstone Dr", "Finch Ave West at John Garland Blvd", "Wilson Ave at Julian Rd East Side (Humber River Hospital)", "Wilson Ave at Julian Rd West Side (Humber River Hospital)", "Gerrard St East at Blantyre Ave East Side", "Gerrard St East at Norwood Rd", "Gerrard St East at Norwood Rd", "Scarlett Rd at Edenbridge Dr North Side", "Main St at Gerrard St East", "Main St at Gerrard St East", "Gerrard St East at Main St", "Gerrard St East at Main St", "Main St at Gerrard St East", "Humber Blvd at Louvain St", "Louvain St at Humber Blvd", "St Clair Ave West at Christie St", "St Clair Ave West at Christie St", "St Clair Ave West at Christie St West Side", "Front St East at Parliament St", "Queen St East at Broadview Ave", "Broadview Ave at Queen St East", "Brimley Rd South at Kingston Rd South Side", "Kingston Rd at Brimley Rd", "Kingston Rd at Beechgrove Dr", "Milner Ave at McCowan Rd East Side", "Yonge St at Cummer Ave", "Cummer Ave at Yonge St East Side", "Sunrise Ave at O'Connor Dr", "O'Connor Dr at Sunrise Ave", "Steeles Ave East at Kelvin Grove Ave", "Keele St at Lawrence Ave West North Side", "Keele St at Lawrence Ave West", "Lawrence Ave West at Keele St", "Harefield Dr at Hinton Rd", "Keele St at Sheppard Ave West North Side", "Sheppard Ave West at Keele St", "Yonge St at Belsize Dr", "Yonge St at Belsize Dr", "350 Morningside Ave (West Hill Collegiate)", "Keele St at Wilson Ave North Side", "Wilson Ave at Keele St North Side", "Wilson Ave at Keele St", "Ellesmere Rd at Kennedy Rd", "Kennedy Rd  ...
